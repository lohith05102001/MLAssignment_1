# %% [markdown]
# <a href="https://colab.research.google.com/github/lohith05102001/MLAssignment_1/blob/main/Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Read the provided CSV file ‘data.csv’.

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/data.csv')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 2. Basic statistical description

# %%
print(df.describe())
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   266.379919
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %% [markdown]
# 3.Check for null values

# %%
print(df.isnull().sum())
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    5
# dtype: int64

# %% [markdown]
# 3a. Replace null values with mean

# %%
print(df.fillna(df.mean(), inplace=True))
# Out:
# None

# %% [markdown]
# 4. Aggregate data for two columns (replace 'Duration' and 'Calories' with your desired columns)

# %%
aggregation = df[['Duration', 'Calories']].agg(['min', 'max', 'count', 'mean'])
print(aggregation)
# Out:
#          Duration     Calories
# min     15.000000    50.300000
# max    300.000000  1860.400000
# count  169.000000   169.000000
# mean    63.846154   375.790244

# %% [markdown]
# 5. Filter rows with calorie (assuming you want non-zero calorie values)

# %%
df_filtered = df[(df['Calories'] > 500) & (df['Calories'] < 1000)]
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %% [markdown]
# 6 Filter the dataframe

# %%
df_filtered = df[(df['Calories'] > 500) & (df['Pulse'] < 100)]
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %% [markdown]
# 7. Create a new dataframe without 'Maxpulse'

# %%
df_modified = df.drop('Maxpulse', axis=1)
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %% [markdown]
# 8. Delete the 'Maxpulse' column from the original dataframe

# %%
df = df.drop('Maxpulse', axis=1)
df
# Out:
#      Duration  Pulse  Calories
# 0          60    110     409.1
# 1          60    117     479.0
# 2          60    103     340.0
# 3          45    109     282.4
# 4          45    117     406.0
# ..        ...    ...       ...
# 164        60    105     290.8
# 165        60    110     300.0
# 166        60    115     310.2
# 167        75    120     320.4
# 168        75    125     330.4
#
# [169 rows x 3 columns]

# %% [markdown]
# 9. Convert the 'Calories' column to integer datatype

# %%
df['Calories'] = df['Calories'].astype(int)
df
# Out:
#      Duration  Pulse  Calories
# 0          60    110       409
# 1          60    117       479
# 2          60    103       340
# 3          45    109       282
# 4          45    117       406
# ..        ...    ...       ...
# 164        60    105       290
# 165        60    110       300
# 166        60    115       310
# 167        75    120       320
# 168        75    125       330
#
# [169 rows x 3 columns]
